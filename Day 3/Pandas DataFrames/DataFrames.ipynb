# %%
# %matplotlib inline

# %% [markdown]
# # Pandas and DataFrames
#
# Often, we have tables of data--collections of named columns arranged in rows.  The **Pandas** package gives us a **DataFrame()** class that lets us index these columns the same way as with dicts, while still getting the benefit of Numpy arrays, meaning we can still write vectorized code.
#
# Let's start playing with the analysis now.  We'll examine Pandas in more depth in the coming days.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Please open the file “MentalRotation.csv” (pd.read_csv()) and use it to answer the following questions about the results of the Mental Rotation psychology experiment. If you reach the end of the exercises, explore the dataset and DataFrames more and see what you can find about this experiment!

# %%
import os
os.getcwd()
# Out:
# '/home/wang/projects/PythonWS/Day 3/Pandas DataFrames'

# %%
data = pd.read_csv('data/MentalRotation.csv')
data
# Out:
#       Subject  Trial  Angle  Matching Response  Time  Correct  Age Sex
# 0          49      1      0         0        n  3107        1   32   M
# 1          49      2    150         0        n  2930        1   32   M
# 2          49      3    150         1        b  1874        1   32   M
# 3          49      4    100         1        b  3793        1   32   M
# 4          49      5     50         1        b  2184        1   32   M
# 5          49      6     50         0        n  1749        1   32   M
# 6          49      7    100         0        b  2592        0   32   M
# 7          49      8      0         1        b  2879        1   32   M
# 8          49      9    150         0        n  7281        1   32   M
# 9          49     10    150         1        b  2386        1   32   M
# 10         49     11     50         0        n  3805        1   32   M
# 11         49     12      0         0        n  1696        1   32   M
# 12         49     13      0         1        b  1440        1   32   M
# 13         49     14    100         0        n  2135        1   32   M
# 14         49     15    100         1        b  2661        1   32   M
# 15         49     16     50         1        b  1989        1   32   M
# 16         49     17    100         0        n  2144        1   32   M
# 17         49     18    150         1        b  3094        1   32   M
# 18         49     19     50         0        n  3388        1   32   M
# 19         49     20     50         1        b  1799        1   32   M
# 20         49     21    100         0        n  4289        1   32   M
# 21         49     22      0         0        n  2279        1   32   M
# 22         49     23      0         1        b  1528        1   32   M
# 23         49     24    150         0        n  3939        1   32   M
# 24         49     25    150         0        n  2659        1   32   M
# 25         49     26     50         0        n  3409        1   32   M
# 26         49     27     50         1        b  2613        1   32   M
# 27         49     28    100         1        b  2963        1   32   M
# 28         49     29      0         1        b  1258        1   32   M
# 29         49     30      0         0        n  2787        1   32   M
# ...       ...    ...    ...       ...      ...   ...      ...  ...  ..
# 5041       33     67    150         1        b  1552        1   20   F
# 5042       33     68      0         0        n   803        1   20   F
# 5043       33     69     50         0        n  2346        1   20   F
# 5044       33     70     50         1        b  1192        1   20   F
# 5045       33     71    100         1        b  1063        1   20   F
# 5046       33     72    100         0        n  2202        1   20   F
# 5047       33     73    100         1        b  1196        1   20   F
# 5048       33     74    100         0        n  1535        1   20   F
# 5049       33     75    150         1        b  2659        1   20   F
# 5050       33     76      0         0        b  2403        0   20   F
# 5051       33     77      0         1        b  1503        1   20   F
# 5052       33     78     50         1        n  1423        0   20   F
# 5053       33     79     50         0        n  1959        1   20   F
# 5054       33     80    150         0        b  1923        0   20   F
# 5055       33     81     50         0        n  1699        1   20   F
# 5056       33     82      0         1        b  1073        1   20   F
# 5057       33     83    150         0        n  5513        1   20   F
# 5058       33     84     50         1        b  1718        1   20   F
# 5059       33     85    100         1        b  1510        1   20   F
# 5060       33     86      0         0        n  2651        1   20   F
# 5061       33     87    150         1        b  3366        1   20   F
# 5062       33     88    100         0        n  2793        1   20   F
# 5063       33     89    100         0        n  1597        1   20   F
# 5064       33     90     50         1        b  1328        1   20   F
# 5065       33     91      0         1        b   828        1   20   F
# 5066       33     92    150         1        b  2095        1   20   F
# 5067       33     93    150         0        n  2125        1   20   F
# 5068       33     94     50         0        n  1226        1   20   F
# 5069       33     95    100         1        b  2783        1   20   F
# 5070       33     96      0         0        n  1017        1   20   F
#
# [5071 rows x 9 columns]

# %% [markdown]
# ## Examining the Dataset
#
# **head()**, **tail()**, **sample()**

# %% [markdown]
# Look at the first 5 lines of the dataset

# %%
data.head(n = 5)
# Out:
#    Subject  Trial  Angle  Matching Response  Time  Correct  Age Sex
# 0       49      1      0         0        n  3107        1   32   M
# 1       49      2    150         0        n  2930        1   32   M
# 2       49      3    150         1        b  1874        1   32   M
# 3       49      4    100         1        b  3793        1   32   M
# 4       49      5     50         1        b  2184        1   32   M

# %%
data.iloc[:5]
# Out:
#    Subject  Trial  Angle  Matching Response  Time  Correct  Age Sex
# 0       49      1      0         0        n  3107        1   32   M
# 1       49      2    150         0        n  2930        1   32   M
# 2       49      3    150         1        b  1874        1   32   M
# 3       49      4    100         1        b  3793        1   32   M
# 4       49      5     50         1        b  2184        1   32   M

# %% [markdown]
# Look at the last 5 lines of the dataset

# %%
data.tail(n=5)
# Out:
#       Subject  Trial  Angle  Matching Response  Time  Correct  Age Sex
# 5066       33     92    150         1        b  2095        1   20   F
# 5067       33     93    150         0        n  2125        1   20   F
# 5068       33     94     50         0        n  1226        1   20   F
# 5069       33     95    100         1        b  2783        1   20   F
# 5070       33     96      0         0        n  1017        1   20   F

# %% [markdown]
# Check 3 random lines in the dataset.

# %%
data.sample(n=3)
# Out:
#       Subject  Trial  Angle  Matching Response  Time  Correct  Age Sex
# 624        15     58    100         0        n  2919        1   21   M
# 1525       10     14    100         0        n  3465        1   20   F
# 1413       38     89    100         0        n  4884        1   22   F

# %% [markdown]
# How Many Total Trials (rows) are in the study?

# %%
data.shape[0]
# Out:
# 5071

# %%
data.count()
# Out:
# Subject     5071
# Trial       5071
# Angle       5071
# Matching    5071
# Response    5071
# Time        5071
# Correct     5071
# Age         5071
# Sex         5071
# dtype: int64

# %% [markdown]
# What is the maximum number of trials that one subject performed?

# %%
data.Trial.max()
# Out:
# 96

# %% [markdown]
# ### Making New Columns

# %% [markdown]
# Convert the Time column to seconds by dividing it by 1000.

# %%
data['Time'] = data['Time']/1000
data.head()
# Out:
#    Subject  Trial  Angle  Matching Response   Time  Correct  Age Sex
# 0       49      1      0         0        n  3.107        1   32   M
# 1       49      2    150         0        n  2.930        1   32   M
# 2       49      3    150         1        b  1.874        1   32   M
# 3       49      4    100         1        b  3.793        1   32   M
# 4       49      5     50         1        b  2.184        1   32   M

# %% [markdown]
# Change the "Correct" column to *bool* (True/False) using the **astype()** method

# %%
data.Correct = data.Correct.astype(dtype=bool)
data.head()
# Out:
#    Subject  Trial  Angle  Matching Response   Time  Correct  Age Sex
# 0       49      1      0         0        n  3.107     True   32   M
# 1       49      2    150         0        n  2.930     True   32   M
# 2       49      3    150         1        b  1.874     True   32   M
# 3       49      4    100         1        b  3.793     True   32   M
# 4       49      5     50         1        b  2.184     True   32   M

# %% [markdown]
# ### The mean() method

# %% [markdown]
# What is the mean response time, across all trials?

# %%
data.Time.mean()
# Out:
# 2.7320932754880696

# %% [markdown]
# What percent of trials were answered correctly?

# %%
np.sum(data.Correct)/len(data)
# Out:
# 0.9045553145336226

# %%
data.Correct.value_counts()
# Out:
# True     4587
# False     484
# Name: Correct, dtype: int64

# %% [markdown]
# What percent of trials were “Matching” trials?

# %%
np.sum(data.Matching == 1)/len(data)
# Out:
# 0.5006901991717609

# %% [markdown]
# ### Slicing

# %% [markdown]
# Is there a difference in accuracy between matching and non-matching trials?

# %%
data.head()
# Out:
#    Subject  Trial  Angle  Matching Response   Time  Correct  Age Sex
# 0       49      1      0         0        n  3.107     True   32   M
# 1       49      2    150         0        n  2.930     True   32   M
# 2       49      3    150         1        b  1.874     True   32   M
# 3       49      4    100         1        b  3.793     True   32   M
# 4       49      5     50         1        b  2.184     True   32   M

# %%
data.columns
# Out:
# Index(['Subject', 'Trial', 'Angle', 'Matching', 'Response', 'Time', 'Correct',
#        'Age', 'Sex'],
#       dtype='object')

# %%
data.values
# Out:
# array([[49, 1, 0, ..., True, 32, 'M'],
#        [49, 2, 150, ..., True, 32, 'M'],
#        [49, 3, 150, ..., True, 32, 'M'],
#        ...,
#        [33, 94, 50, ..., True, 20, 'F'],
#        [33, 95, 100, ..., True, 20, 'F'],
#        [33, 96, 0, ..., True, 20, 'F']], dtype=object)

# %% [markdown]
# Is there a response time difference between matching and nonmatching
# trials?

# %%
data.index
# Out:
# RangeIndex(start=0, stop=5071, step=1)

# %%
print('0: {}'.format(data[data.Matching == 0].Time.mean()))
print('0: {}'.format(data[data.Matching == 1].Time.mean()))
# Out:
# 0: 2.84253317535545
# 0: 2.621957857424183

# %%
from scipy.stats import ttest_ind
ttest_ind(data[data.Matching == 0].Time, data[data.Matching == 1].Time)
# Out:
# Ttest_indResult(statistic=5.571026559512821, pvalue=2.663138203125879e-08)

# %% [markdown]
# Is there a response time difference between matching and nonmatching trials, for different rotation Angles?

# %%
data.head()
# Out:
#    Subject  Trial  Angle  Matching Response   Time  Correct  Age Sex
# 0       49      1      0         0        n  3.107     True   32   M
# 1       49      2    150         0        n  2.930     True   32   M
# 2       49      3    150         1        b  1.874     True   32   M
# 3       49      4    100         1        b  3.793     True   32   M
# 4       49      5     50         1        b  2.184     True   32   M

# %%
data.groupby('Matching').Correct.mean()
# Out:
# Matching
# 0    0.909163
# 1    0.899961
# Name: Correct, dtype: float64

# %%
data.groupby(['Matching', 'Angle']).Correct.mean()
# Out:
# Matching  Angle
# 0         0        0.924647
#           50       0.949843
#           100      0.897764
#           150      0.863708
# 1         0        0.984301
#           50       0.922118
#           100      0.880315
#           150      0.811200
# Name: Correct, dtype: float64

# %%
data.groupby(['Matching', 'Angle']).Correct.mean().unstack()
# Out:
# Angle          0         50        100       150
# Matching
# 0         0.924647  0.949843  0.897764  0.863708
# 1         0.984301  0.922118  0.880315  0.811200

# %%
data.groupby(['Matching', 'Angle']).Correct.mean().unstack().T
# Out:
# Matching         0         1
# Angle
# 0         0.924647  0.984301
# 50        0.949843  0.922118
# 100       0.897764  0.880315
# 150       0.863708  0.811200

# %% [markdown]
# ### Plotting

# %% [markdown]
# Plot the response time distribution as a histogram.

# %%
data.Time.hist()

# %%
import seaborn as sns

# %%
sns.distplot(data.Time)

# %% [markdown]
# Plot the average response time for each stimulus category (matching and non-matching)

# %%
data.groupby('Matching').Time.mean().plot.bar()

# %%
sns.barplot(data=data, x='Matching', y='Time')

# %%
sns.violinplot(data=data, x='Matching', y='Time')

# %% [markdown]
# Is there a correlation between Angle of mental rotation and response time?  Visualize the relationship

# %%
sns.catplot(data=data, x='Matching', y='Time', kind='boxen')

# %%
data.head()
# Out:
#    Subject  Trial  Angle  Matching Response   Time  Correct  Age Sex
# 0       49      1      0         0        n  3.107     True   32   M
# 1       49      2    150         0        n  2.930     True   32   M
# 2       49      3    150         1        b  1.874     True   32   M
# 3       49      4    100         1        b  3.793     True   32   M
# 4       49      5     50         1        b  2.184     True   32   M

# %%
data.Angle.value_counts()
# Out:
# 50     1280
# 0      1274
# 100    1261
# 150    1256
# Name: Angle, dtype: int64

# %%
sns.catplot(data=data, x='Angle', y='Time', kind='point',
           hue='Matching')

# %%
data.groupby('Angle').Time.mean().plot.bar()

# %% [markdown]
# Is there a difference in the relationship between Angle of mental rotation and response time, between stimulus categories?

# %%
data.head()
# Out:
#    Subject  Trial  Angle  Matching Response   Time  Correct  Age Sex
# 0       49      1      0         0        n  3.107     True   32   M
# 1       49      2    150         0        n  2.930     True   32   M
# 2       49      3    150         1        b  1.874     True   32   M
# 3       49      4    100         1        b  3.793     True   32   M
# 4       49      5     50         1        b  2.184     True   32   M

# %%
import seaborn as sns
sns.set(style="ticks")
exercise = sns.load_dataset("exercise")
g = sns.catplot(x="time", y="pulse", hue="kind", data=exercise)

# %%
exercise.head()
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest

# %%
import os
os.getcwd()
# Out:
# '/home/wang/projects/PythonWS/Day 3/Pandas DataFrames'

# %%
df = pd.read_excel('mess.xlsx')
df = df[df.x > 2][['x', 'y', 'genes']]
df.head()
# Out:
#    x  y  genes
# 0  3  1    NaN
# 2  5  3    NaN
# 3  4  4    NaN

# %%
data.head()
# Out:
#    Subject  Trial  Angle  Matching Response   Time  Correct  Age Sex
# 0       49      1      0         0        n  3.107     True   32   M
# 1       49      2    150         0        n  2.930     True   32   M
# 2       49      3    150         1        b  1.874     True   32   M
# 3       49      4    100         1        b  3.793     True   32   M
# 4       49      5     50         1        b  2.184     True   32   M

# %%
# Out:
#    CountryName CountryCode                             IndicatorName  \
# 0        Aruba         ABW  Fertility rate, total (births per woman)
# 1      Andorra         AND  Fertility rate, total (births per woman)
# 2  Afghanistan         AFG  Fertility rate, total (births per woman)
# 3       Angola         AGO  Fertility rate, total (births per woman)
# 4      Albania         ALB  Fertility rate, total (births per woman)
#
#     IndicatorCode   1960   1961   1962   1963   1964   1965  ...   2004  \
# 0  SP.DYN.TFRT.IN  4.820  4.655  4.471  4.271  4.059  3.842  ...  1.786
# 1  SP.DYN.TFRT.IN    NaN    NaN    NaN    NaN    NaN    NaN  ...    NaN
# 2  SP.DYN.TFRT.IN  7.671  7.671  7.671  7.671  7.671  7.671  ...  7.136
# 3  SP.DYN.TFRT.IN  7.316  7.354  7.385  7.410  7.425  7.430  ...  6.704
# 4  SP.DYN.TFRT.IN  6.186  6.076  5.956  5.833  5.711  5.594  ...  2.004
#
#     2005   2006   2007   2008   2009   2010   2011  2012  2013
# 0  1.769  1.754  1.739  1.726  1.713  1.701  1.690   NaN   NaN
# 1    NaN  1.240  1.180  1.250  1.190  1.220    NaN   NaN   NaN
# 2  6.930  6.702  6.456  6.196  5.928  5.659  5.395   NaN   NaN
# 3  6.657  6.598  6.523  6.434  6.331  6.218  6.099   NaN   NaN
# 4  1.919  1.849  1.796  1.761  1.744  1.741  1.748   NaN   NaN
#
# [5 rows x 58 columns]

# %%
from glob import glob
import pandas as pd


os.chdir('/home/wang/projects/PythonWS/Day 3')

files = glob('*.csv')
files
# Out:
# ['example.csv', 'worldbankdata.csv']

# %%
data = pd.read_csv(files[1])
data.head()
# Out:
#    CountryName CountryCode                             IndicatorName  \
# 0        Aruba         ABW  Fertility rate, total (births per woman)
# 1      Andorra         AND  Fertility rate, total (births per woman)
# 2  Afghanistan         AFG  Fertility rate, total (births per woman)
# 3       Angola         AGO  Fertility rate, total (births per woman)
# 4      Albania         ALB  Fertility rate, total (births per woman)
#
#     IndicatorCode   1960   1961   1962   1963   1964   1965  ...   2004  \
# 0  SP.DYN.TFRT.IN  4.820  4.655  4.471  4.271  4.059  3.842  ...  1.786
# 1  SP.DYN.TFRT.IN    NaN    NaN    NaN    NaN    NaN    NaN  ...    NaN
# 2  SP.DYN.TFRT.IN  7.671  7.671  7.671  7.671  7.671  7.671  ...  7.136
# 3  SP.DYN.TFRT.IN  7.316  7.354  7.385  7.410  7.425  7.430  ...  6.704
# 4  SP.DYN.TFRT.IN  6.186  6.076  5.956  5.833  5.711  5.594  ...  2.004
#
#     2005   2006   2007   2008   2009   2010   2011  2012  2013
# 0  1.769  1.754  1.739  1.726  1.713  1.701  1.690   NaN   NaN
# 1    NaN  1.240  1.180  1.250  1.190  1.220    NaN   NaN   NaN
# 2  6.930  6.702  6.456  6.196  5.928  5.659  5.395   NaN   NaN
# 3  6.657  6.598  6.523  6.434  6.331  6.218  6.099   NaN   NaN
# 4  1.919  1.849  1.796  1.761  1.744  1.741  1.748   NaN   NaN
#
# [5 rows x 58 columns]
