# %%
dict1 = {'a':1, 'b':2}

# %%
globals()['dict1']
# Out:
# {'a': 1, 'b': 2}

# %%
list(dict1.keys())
# Out:
# ['a', 'b']

# %%
list(dict1.values())
# Out:
# [1, 2]

# %%
import pandas as pd

# %%
df = pd.DataFrame()

# %%
df["Country"] = ['Germany', 'France', 'England']
df['Pop'] = [30, 24, 26]
df
# Out:
#    Country  Pop
# 0  Germany   30
# 1   France   24
# 2  England   26

# %%
df.iloc[[0, 2]]
# Out:
#    Country  Pop
# 0  Germany   30
# 2  England   26

# %%
df.loc[[0, 2]]
# Out:
#    Country  Pop
# 0  Germany   30
# 2  England   26

# %%
df1 = df.set_index('Country')
df1
# Out:
#          Pop
# Country
# Germany   30
# France    24
# England   26

# %%
df1.loc[['Germany']]
# Out:
#          Pop
# Country
# Germany   30

# %%
df.Country
# Out:
# 0    Germany
# 1     France
# 2    England
# Name: Country, dtype: object

# %%
df.Pop.mean()
# Out:
# 26.666666666666668

# %%
import numpy as np
np.mean(df.Pop)
# Out:
# 26.666666666666668

# %%
df.Pop.values
# Out:
# array([30, 24, 26])

# %%
df.Pop.tolist()
# Out:
# [30, 24, 26]

# %%
df.plot.bar(x='Country', y ='Pop')

# %%
df.head()
# Out:
#    Country  Pop
# 0  Germany   30
# 1   France   24
# 2  England   26

# %%
df.tail()
# Out:
#    Country  Pop
# 0  Germany   30
# 1   France   24
# 2  England   26

# %%
df.sample(2)
# Out:
#    Country  Pop
# 2  England   26
# 1   France   24

# %%
df[df['Pop'] > 25]
# Out:
#    Country  Pop  COUNTRY
# 0  Germany   30  GERMANY
# 2  England   26  ENGLAND

# %%
df[df['Pop'] > 25]
# Out:
# Country    Germany
# Pop             30
# COUNTRY    GERMANY
# Name: 0, dtype: object

# %%
df['COUNTRY'] = df.Country.str.upper()
df
# Out:
#    Country  Pop  COUNTRY
# 0  Germany   30  GERMANY
# 1   France   24   FRANCE
# 2  England   26  ENGLAND

# %%
df.to_csv('example.csv')

# %%
df.to_html('example.html')

# %%
df = pd.read_csv('worldbankdata.csv')
df
# Out:
#                         CountryName CountryCode  \
# 0                             Aruba         ABW
# 1                           Andorra         AND
# 2                       Afghanistan         AFG
# 3                            Angola         AGO
# 4                           Albania         ALB
# 5              United Arab Emirates         ARE
# 6                         Argentina         ARG
# 7                           Armenia         ARM
# 8                    American Samoa         ASM
# 9               Antigua and Barbuda         ATG
# 10                        Australia         AUS
# 11                          Austria         AUT
# 12                       Azerbaijan         AZE
# 13                          Burundi         BDI
# 14                          Belgium         BEL
# 15                            Benin         BEN
# 16                     Burkina Faso         BFA
# 17                       Bangladesh         BGD
# ...
